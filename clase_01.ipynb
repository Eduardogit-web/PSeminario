# %% [markdown]
# <a href="https://colab.research.google.com/github/we-human-centric/CursoPythonDatos_2026/blob/main/Dia%2001%20-%202026-04-21%20-%20Kick-off%20del%20seminario/clase_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# Bienvenidos. Hoy hacemos tres cosas: verificar que el entorno funciona, escribir nuestras primeras líneas, y dejar todo listo para los próximos tres meses.
#
# Si algo falla—Python no está, Jupyter no anda, terminal grita error—mejor que pase ahora. Arreglamos y después te concentras en aprender, no en debuggear.
#
# Ejecuta cada celda con Shift + Enter.

# %% [markdown]
# > **Hoy haces** · Verificar el entorno (Python, Jupyter, Git), formar equipo de 3, elegir el caso y crear el repo del equipo. ~2h30.
# >
# > **Entrega** · Un repositorio GitHub con el README del equipo (nombre del proyecto, integrantes, caso elegido) antes de la clase 2.

# %%
import sys
import random
import numpy as np
import pandas as pd

SEED = 42
random.seed(SEED)
np.random.seed(SEED)

print(f"Python {sys.version.split()[0]} ✓")
print(f"NumPy {np.__version__} ✓")
print(f"Pandas {pd.__version__} ✓")
print("\nSetup completo ✓")
# Out:
# Python 3.12.13 ✓
# NumPy 2.0.2 ✓
# Pandas 2.2.2 ✓
#
# Setup completo ✓

# %% [markdown]
# Si ves checkmarks, estamos bien. Si ves rojo, descomenta `!pip install` en la siguiente celda.

# %%
# !pip install --quiet pandas numpy matplotlib seaborn

nombre = "Seminario EDA"
anio = 2026
estudiantes = 15

print(f"Bienvenidos al {nombre} {anio}")
print(f"Somos {estudiantes} personas en este viaje")
# Out:
# Bienvenidos al Seminario EDA 2026
# Somos 15 personas en este viaje

# %% [markdown]
# Eso que ves es lo esencial: variables, datos, un print que habla. Mañana entendemos *cómo* funciona. Hoy es solo: "esto corre".
#
# Detalle importante: en Python los nombres de variables usan `snake_case` (palabras en minúscula, separadas por guion bajo). Es convención; todos la usan. Mejor seguirla desde el inicio.

# %%
# Guiado: calcula el promedio de tres números
num1 = 10
num2 = 20
num3 = 30

promedio = (num1 + num2 + num3) / 3
print(f"El promedio es: {promedio}")

assert promedio == 20.0
print("✓ Correcto")
# Out:
# El promedio es: 20.0
# ✓ Correcto

# %% [markdown]
# Viste ese `assert`? Es una línea que dice: "si esto no es verdad, grita un error". Los usamos para validar ejercicios. Si el assert pasa sin ruido, estás bien.

# %%
# Ahora con dinero. Tres ventas del día de un vendedor.
venta1 = 150.50
venta2 = 200.00
venta3 = 75.25

total_ventas = venta1 + venta2 + venta3
comision = total_ventas * 0.10  # 10% de comisión

print(f"Total de ventas: ${total_ventas:.2f}")
print(f"Tu comisión (10%): ${comision:.2f}")

assert abs(total_ventas - 425.75) < 0.01
print("✓ Cálculo correcto")
# Out:
# Total de ventas: $425.75
# Tu comisión (10%): $42.58
# ✓ Cálculo correcto

# %% [markdown]
# Ves el `.2f`? Formato que dice: "muestra dos decimales". Con dinero, siempre quieres eso.
#
# Y ese `abs(...) < 0.01` es un truco para evitar problemas raros de precisión con decimales. Detalle que veremos.

# %%
# Ejercicio aplicado:
# Un cuadrado de lado 5. Calcula el área.
# Área = lado × lado

lado = 5
area = lado * lado

print(f"Lado: {lado}")
print(f"Área: {area}")

assert area == 25
print("✓ Ejercicio aplicado completado")
# Out:
# Lado: 5
# Área: 25
# ✓ Ejercicio aplicado completado

# %%
# Ejercicio desafío (sin andamiaje):
# Un cliente compra: A=$25.99 B=$10.50 C=$45.00
# Calcula: subtotal, IVA (12%), total a pagar

precio_a = 25.99
precio_b = 10.50
precio_c = 45.00

subtotal = precio_a + precio_b + precio_c
iva = subtotal * 0.12
total = round(subtotal + iva, 2)

print(f"Subtotal: ${subtotal:.2f}")
print(f"IVA (12%): ${iva:.2f}")
print(f"Total a pagar: ${total:.2f}")

assert abs(total - 91.2688) < 0.01
print("✓ Ejercicio desafío completado")
# Out:
# Subtotal: $81.49
# IVA (12%): $9.78
# Total a pagar: $91.27
# ✓ Ejercicio desafío completado

# %% [markdown]
# Ahora lo más importante: ¿cómo guardas esto para tu equipo? Con Git. En la terminal de tu computadora (no en Colab):

# %% [markdown]
# ```bash
# cd seminario-eda/
# git init
# git add clase_01.ipynb
# git commit -m "primer commit: setup y ejercicios básicos"
# ```
#
# Si no sabes qué es eso, pregunta. Git es nuevo para casi todos, y mejor aprenderlo bien de entrada.

# %% [markdown]
# > **Recordatorio** · Repo del equipo creado y compartido en el canal antes de la próxima sesión.

# %% [markdown]
# Eso es todo por hoy.
#
# Lo que hiciste: instalaste el entorno, escribiste código que funciona, lo validaste, y lo guardaste. Parece poco, pero es *todo*. Mañana empezamos con tipos, operadores y strings; el día después, listas y funciones. Cada cosa que aprenderás se apoya en esto.
#
# Si algo no quedó claro, mejor pregunta ahora. En programación las dudas se apilan rápido, y de repente estás bloqueado en pandas por algo de hoy que podrías haber arreglado en cinco minutos.
#
# Antes de irte: confirma que tu equipo tiene un repositorio GitHub compartido (aunque sea privado) con un README mínimo. Mañana empezamos a llenar ese repo con código real.
